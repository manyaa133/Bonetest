# %% [markdown]
# # Bone Age Predictor — Colab Training
#
# Enable **GPU**: Runtime → Change runtime type → T4 GPU
#
# Dataset: [RSNA Pediatric Bone Age](https://www.kaggle.com/competitions/rsna-bone-age)

# %%
# !git clone https://github.com/your-org/bone-age-predictor.git  # or upload backend/
# %cd bone-age-predictor/backend
# !pip install -r requirements.txt

# %%
# Mount Kaggle dataset (after uploading RSNA data to Colab or using kaggle API)
DATA_DIR = '/content/rsna-bone-age'  # update path
import os; assert os.path.exists(DATA_DIR), 'Set DATA_DIR to RSNA dataset path'

# %%
for model in ['cnn', 'cnn_dnn', 'multimodal_cnn', 'cnn_rf']:
    # !python -m ml.train --model-type {model} --data-dir {DATA_DIR} --epochs 30 --pretrained --batch-size 16

# %%
# !python -m ml.evaluate --data-dir {DATA_DIR}
# !python -m ml.compare_models
# !zip -r bone_age_artifacts.zip checkpoints rf_models metrics
